# %% [markdown]
# # Análise de anotações de variantes dos genes causadores de CCFP no ABRAOM
#
# Neste projeto nós vamos analisar quais são as anotações das variantes para os cinco genes da Calcificação Cerebral Familiar Primária da coorte SABE609.
# Os genes são SLC20A2, XPR1, PDGFB, PDGFRB, KIAA1161 e JAM2.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ABRaOM_60+_SABE_609_exomes_annotated', sep='\t', encoding='latin1')
# Out:
# /home/denis/anaconda3/envs/python362/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# O arquivo contendo informações das variantes foi disponibilizado no website da Arquivo Brasileiro Online de Mutações (ABraOM, http://abraom.ib.usp.br/), na página de Downloads.

# %%
df.head()
# Out:
#   Chr  Start Ref Alt PredictedFunc.refGene Gene.refGene  \
# 0   1  13116   T   G        ncRNA_intronic      DDX11L1
# 1   1  13244   G   A          ncRNA_exonic      DDX11L1
# 2   1  13248   C   G          ncRNA_exonic      DDX11L1
# 3   1  13273   G   C          ncRNA_exonic      DDX11L1
# 4   1  13302   C   T          ncRNA_exonic      DDX11L1
#
#   PredConsequence.refGene     avsnp147                      FILTER  \
# 0                     NaN   rs62635286                     LowQual
# 1                     NaN          NaN                     LowQual
# 2                     NaN          NaN  VQSRTrancheSNP99.00to99.90
# 3                     NaN  rs531730856  VQSRTrancheSNP99.00to99.90
# 4                     NaN  rs180734498  VQSRTrancheSNP99.00to99.90
#
#   CEGH Filter  HomozygousALT count  Hemizygous count  Allele number  \
# 0         FDP                    2                 0            598
# 1         FAB                    0                 0            456
# 2         FAB                    0                 0            482
# 3  WK-LowCall                   20                 0            600
# 4  WK-LowCall                    1                 0            700
#
#    Allele ALT count  Frequencies   Cohort
# 0                 6     0.010033  SABE609
# 1                 1     0.002193  SABE609
# 2                 2     0.004149  SABE609
# 3                68     0.113333  SABE609
# 4                12     0.017143  SABE609

# %% [markdown]
# O banco de dados está organizado, por amostra, em 16 colunas.
#
# Chr: Qual cromossomo aquela amostra pertence;<br>
# Start: Posição cromossômica que inicia aquela variação (hg19);<br>
# Ref: Nucleotídeo de referência para aquela posição, no genoma de referência;<br>
# Alt: Nucleotídeo alternativo presente naquela posição do genoma;<br>
# PredictedFunc.refGene: Qual a parte do gene referência daquela posição;<br>
# Gene.refGene: Gene referência da posição;<br>
# PredConsequence.refGene: Consequência predita daquela variação ao gene referência;<br>
# avsnp147:<br>
# FILTER:<br>
# CEGH Filter:<br>
# HomozygousALT count:<br>
# Hemizygous count:<br>
# Allele number:<br>
# Allele ALT count:<br>
# Frequencies: Frequências daquela variante no banco de dados (frequência da variante na população brasileira);<br>
# Cohort: A coorte a qual a amostra pertence.

# %%
len(df['Gene.refGene'].unique())
# Out:
# 28127

# %%
slc20a2 = df[df['Gene.refGene'].str.contains('SLC20A2')]
slc20a2
# Out:
#         Chr     Start Ref Alt PredictedFunc.refGene    Gene.refGene  \
# 1012090   8  42274108   A   G                  UTR3         SLC20A2
# 1012091   8  42274264   G   C                  UTR3         SLC20A2
# 1012092   8  42274303   C   A                  UTR3         SLC20A2
# 1012093   8  42274448   C   A                  UTR3         SLC20A2
# 1012094   8  42274751   C   A                  UTR3         SLC20A2
# ...      ..       ...  ..  ..                   ...             ...
# 1012218   8  42397004   C   T                  UTR5  SLC20A2,SMIM19
# 1012219   8  42397233   T   A                  UTR5  SLC20A2,SMIM19
# 1012220   8  42397291   G   A                  UTR5  SLC20A2,SMIM19
# 1012221   8  42397310   G   T                  UTR5  SLC20A2,SMIM19
# 1012222   8  42397337   G   T                  UTR5  SLC20A2,SMIM19
#
#                                    PredConsequence.refGene     avsnp147  \
# 1012090  NM_006749:c.*1213T>C,NM_001257181:c.*1213T>C,N...          NaN
# 1012091  NM_006749:c.*1057C>G,NM_001257181:c.*1057C>G,N...       rs6841
# 1012092  NM_006749:c.*1018G>T,NM_001257181:c.*1018G>T,N...          NaN
# 1012093  NM_006749:c.*873G>T,NM_001257181:c.*873G>T,NM_...          NaN
# 1012094  NM_006749:c.*570G>T,NM_001257181:c.*570G>T,NM_...    rs1803657
# ...                                                    ...          ...
# 1012218  NM_006749:c.-67096G>A;NM_001135674:c.-4612C>T,...    rs2923444
# 1012219  NM_006749:c.-67325A>T;NM_001135674:c.-4383T>A,...  rs113755761
# 1012220  NM_006749:c.-67383C>T;NM_001135674:c.-4325G>A,...  rs145711927
# 1012221      NM_006749:c.-67402C>A;NM_001135674:c.-4306G>T          NaN
# 1012222      NM_006749:c.-67429C>A;NM_001135674:c.-4279G>T          NaN
#
#           FILTER CEGH Filter  HomozygousALT count  Hemizygous count  \
# 1012090     PASS         FDP                    1                 0
# 1012091     PASS         FDP                   14                 0
# 1012092  LowQual         FDP                    1                 0
# 1012093  LowQual         FDP                    0                 0
# 1012094     PASS         FDP                   14                 0
# ...          ...         ...                  ...               ...
# 1012218     PASS         FDP                  201                 0
# 1012219     PASS         FDP                    5                 0
# 1012220     PASS         FDP                    1                 0
# 1012221  LowQual         FDP                    1                 0
# 1012222  LowQual         FDP                    1                 0
#
#          Allele number  Allele ALT count  Frequencies   Cohort
# 1012090            196                 2     0.010204  SABE609
# 1012091            264                32     0.121212  SABE609
# 1012092            340                 2     0.005882  SABE609
# 1012093            542                 1     0.001845  SABE609
# 1012094            252                28     0.111111  SABE609
# ...                ...               ...          ...      ...
# 1012218            658               440     0.668693  SABE609
# 1012219            566                16     0.028269  SABE609
# 1012220            590                 6     0.010169  SABE609
# 1012221            612                 2     0.003268  SABE609
# 1012222            662                 2     0.003021  SABE609
#
# [130 rows x 16 columns]

# %%
pfbcAbraom = {'SLC20A2': df[df['Gene.refGene'].str.contains('SLC20A2')],
             'XPR1': df[df['Gene.refGene'].str.contains('XPR1')],
             'PDGFB': df[df['Gene.refGene'].str.contains('PDGFB')],
             'PDGFRB': df[df['Gene.refGene'].str.contains('PDGFRB')],
             'KIAA1161': df[df['Gene.refGene'].str.contains('KIAA1161')],
             'JAM2': df[df['Gene.refGene'].str.contains('JAM2')]}

# %%
pfbcAbraom.keys()
# Out:
# dict_keys(['SLC20A2', 'XPR1', 'PDGFB', 'PDGFRB', 'KIAA1161', 'JAM2'])

# %%
pfbcAbraom['SLC20A2']
# Out:
#         Chr     Start Ref Alt PredictedFunc.refGene    Gene.refGene  \
# 1012090   8  42274108   A   G                  UTR3         SLC20A2
# 1012091   8  42274264   G   C                  UTR3         SLC20A2
# 1012092   8  42274303   C   A                  UTR3         SLC20A2
# 1012093   8  42274448   C   A                  UTR3         SLC20A2
# 1012094   8  42274751   C   A                  UTR3         SLC20A2
# ...      ..       ...  ..  ..                   ...             ...
# 1012218   8  42397004   C   T                  UTR5  SLC20A2,SMIM19
# 1012219   8  42397233   T   A                  UTR5  SLC20A2,SMIM19
# 1012220   8  42397291   G   A                  UTR5  SLC20A2,SMIM19
# 1012221   8  42397310   G   T                  UTR5  SLC20A2,SMIM19
# 1012222   8  42397337   G   T                  UTR5  SLC20A2,SMIM19
#
#                                    PredConsequence.refGene     avsnp147  \
# 1012090  NM_006749:c.*1213T>C,NM_001257181:c.*1213T>C,N...          NaN
# 1012091  NM_006749:c.*1057C>G,NM_001257181:c.*1057C>G,N...       rs6841
# 1012092  NM_006749:c.*1018G>T,NM_001257181:c.*1018G>T,N...          NaN
# 1012093  NM_006749:c.*873G>T,NM_001257181:c.*873G>T,NM_...          NaN
# 1012094  NM_006749:c.*570G>T,NM_001257181:c.*570G>T,NM_...    rs1803657
# ...                                                    ...          ...
# 1012218  NM_006749:c.-67096G>A;NM_001135674:c.-4612C>T,...    rs2923444
# 1012219  NM_006749:c.-67325A>T;NM_001135674:c.-4383T>A,...  rs113755761
# 1012220  NM_006749:c.-67383C>T;NM_001135674:c.-4325G>A,...  rs145711927
# 1012221      NM_006749:c.-67402C>A;NM_001135674:c.-4306G>T          NaN
# 1012222      NM_006749:c.-67429C>A;NM_001135674:c.-4279G>T          NaN
#
#           FILTER CEGH Filter  HomozygousALT count  Hemizygous count  \
# 1012090     PASS         FDP                    1                 0
# 1012091     PASS         FDP                   14                 0
# 1012092  LowQual         FDP                    1                 0
# 1012093  LowQual         FDP                    0                 0
# 1012094     PASS         FDP                   14                 0
# ...          ...         ...                  ...               ...
# 1012218     PASS         FDP                  201                 0
# 1012219     PASS         FDP                    5                 0
# 1012220     PASS         FDP                    1                 0
# 1012221  LowQual         FDP                    1                 0
# 1012222  LowQual         FDP                    1                 0
#
#          Allele number  Allele ALT count  Frequencies   Cohort
# 1012090            196                 2     0.010204  SABE609
# 1012091            264                32     0.121212  SABE609
# 1012092            340                 2     0.005882  SABE609
# 1012093            542                 1     0.001845  SABE609
# 1012094            252                28     0.111111  SABE609
# ...                ...               ...          ...      ...
# 1012218            658               440     0.668693  SABE609
# 1012219            566                16     0.028269  SABE609
# 1012220            590                 6     0.010169  SABE609
# 1012221            612                 2     0.003268  SABE609
# 1012222            662                 2     0.003021  SABE609
#
# [130 rows x 16 columns]

# %%
nsVar = {'SLC20A2': pfbcAbraom['SLC20A2'][pfbcAbraom['SLC20A2']['PredictedFunc.refGene'].str.contains('nonsynonymous SNV')],
        'XPR1': pfbcAbraom['XPR1'][pfbcAbraom['XPR1']['PredictedFunc.refGene'].str.contains('nonsynonymous SNV')],
        'PDGFB': pfbcAbraom['PDGFB'][pfbcAbraom['PDGFB']['PredictedFunc.refGene'].str.contains('nonsynonymous SNV')],
        'PDGFRB': pfbcAbraom['PDGFRB'][pfbcAbraom['PDGFRB']['PredictedFunc.refGene'].str.contains('nonsynonymous SNV')],
        'KIAA1161': pfbcAbraom['KIAA1161'][pfbcAbraom['KIAA1161']['PredictedFunc.refGene'].str.contains('nonsynonymous SNV')],
        'JAM2': pfbcAbraom['JAM2'][pfbcAbraom['JAM2']['PredictedFunc.refGene'].str.contains('nonsynonymous SNV')]}

# %%
for var in nsVar['SLC20A2']['PredConsequence.refGene']:
    print(var)
# Out:
# SLC20A2:NM_001257180:exon8:c.G1438A:p.A480T,SLC20A2:NM_001257181:exon8:c.G1438A:p.A480T,SLC20A2:NM_006749:exon8:c.G1438A:p.A480T
# SLC20A2:NM_001257180:exon8:c.C1316T:p.A439V,SLC20A2:NM_001257181:exon8:c.C1316T:p.A439V,SLC20A2:NM_006749:exon8:c.C1316T:p.A439V
# SLC20A2:NM_001257180:exon8:c.C1223T:p.S408L,SLC20A2:NM_001257181:exon8:c.C1223T:p.S408L,SLC20A2:NM_006749:exon8:c.C1223T:p.S408L
# SLC20A2:NM_001257180:exon8:c.G1198A:p.A400T,SLC20A2:NM_001257181:exon8:c.G1198A:p.A400T,SLC20A2:NM_006749:exon8:c.G1198A:p.A400T
# SLC20A2:NM_001257180:exon7:c.G910A:p.G304S,SLC20A2:NM_001257181:exon7:c.G910A:p.G304S,SLC20A2:NM_006749:exon7:c.G910A:p.G304S
# SLC20A2:NM_001257180:exon7:c.G761A:p.R254Q,SLC20A2:NM_001257181:exon7:c.G761A:p.R254Q,SLC20A2:NM_006749:exon7:c.G761A:p.R254Q
# SLC20A2:NM_001257180:exon5:c.A533G:p.N178S,SLC20A2:NM_001257181:exon5:c.A533G:p.N178S,SLC20A2:NM_006749:exon5:c.A533G:p.N178S
# SLC20A2:NM_001257180:exon2:c.A145G:p.I49V,SLC20A2:NM_001257181:exon2:c.A145G:p.I49V,SLC20A2:NM_006749:exon2:c.A145G:p.I49V
# SLC20A2:NM_001257180:exon2:c.T44C:p.I15T,SLC20A2:NM_001257181:exon2:c.T44C:p.I15T,SLC20A2:NM_006749:exon2:c.T44C:p.I15T

# %%
for var in nsVar['SLC20A2']['PredConsequence.refGene']:
    print(var.find(':', 27))
# Out:
# 35
# 35
# 35
# 35
# 34
# 34
# 34
# 34
# 33

# %%
for var in nsVar['SLC20A2']['PredConsequence.refGene']:
    print(var[27:(var.find(':', 27))])
# Out:
# c.G1438A
# c.C1316T
# c.C1223T
# c.G1198A
# c.G910A
# c.G761A
# c.A533G
# c.A145G
# c.T44C

# %%
varAnnot = dict()
def extractNSVar(dictionary, gene):
    cdsChange = []
    proteinChange = []
    frequency = []
    alleleNum = []
    filterpass = []
    for var in nsVar[gene]['PredConsequence.refGene']:
        if ',' in var:
        #print(var[var.find('p.'):var.find(',')])
            cdsChange.append(var[var.find('c.'):var.find(':p.')])
            proteinChange.append(var[var.find('p.'):var.find(',')])
        else:
            cdsChange.append(var[var.find('c.'):var.find(':p.')])
            proteinChange.append(var[var.find('p.'):])
    
    for var in nsVar[gene]['Frequencies']:
        frequency.append(var)
        
    for var in nsVar[gene]['Allele number']:
        alleleNum.append(var)
        
    for var in nsVar[gene]['FILTER']:
        filterpass.append(var)
    
    varAnnot[gene] = (list(zip(cdsChange, proteinChange, frequency, alleleNum, filterpass)))

# %%
for var in nsVar['PDGFB']['PredConsequence.refGene']:
    if ',' in var:
        print(var[var.find('p.'):var.find(',')])
    else:
        print(var[var.find('p.'):])
# Out:
# p.H228N
# p.P219L
# p.T212M
# p.Q145R
# p.C12F

# %%
for key in nsVar:
    extractNSVar(nsVar, key)

# %%
varAnnot['SLC20A2']
# Out:
# [('c.G1438A', 'p.A480T', 0.00821, 1218, 'PASS'),
#  ('c.C1316T', 'p.A439V', 0.0008210000000000001, 1218, 'PASS'),
#  ('c.C1223T', 'p.S408L', 0.0008210000000000001, 1218, 'PASS'),
#  ('c.G1198A', 'p.A400T', 0.0016420000000000002, 1218, 'PASS'),
#  ('c.G910A', 'p.G304S', 0.050082, 1218, 'PASS'),
#  ('c.G761A', 'p.R254Q', 0.0008210000000000001, 1218, 'PASS'),
#  ('c.A533G', 'p.N178S', 0.0016420000000000002, 1218, 'PASS'),
#  ('c.A145G', 'p.I49V', 0.0008210000000000001, 1218, 'PASS'),
#  ('c.T44C', 'p.I15T', 0.0008210000000000001, 1218, 'PASS')]

# %%
varAnnot
# Out:
# {'SLC20A2': [('c.G1438A', 'p.A480T', 0.00821, 1218, 'PASS'),
#   ('c.C1316T', 'p.A439V', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.C1223T', 'p.S408L', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.G1198A', 'p.A400T', 0.0016420000000000002, 1218, 'PASS'),
#   ('c.G910A', 'p.G304S', 0.050082, 1218, 'PASS'),
#   ('c.G761A', 'p.R254Q', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.A533G', 'p.N178S', 0.0016420000000000002, 1218, 'PASS'),
#   ('c.A145G', 'p.I49V', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.T44C', 'p.I15T', 0.0008210000000000001, 1218, 'PASS')],
#  'XPR1': [('c.G527T', 'p.R176L', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.G1310A', 'p.R437Q', 0.0008210000000000001, 1218, 'LowQual'),
#   ('c.T1811C', 'p.L604P', 0.0008210000000000001, 1218, 'PASS')],
#  'PDGFB': [('c.C682A', 'p.H228N', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.C656T', 'p.P219L', 0.0032840000000000005, 1218, 'PASS'),
#   ('c.C635T', 'p.T212M', 0.0057469999999999995, 1218, 'PASS'),
#   ('c.A434G', 'p.Q145R', 0.000822, 1216, 'PASS'),
#   ('c.G35T', 'p.C12F', 0.0008210000000000001, 1218, 'PASS')],
#  'PDGFRB': [('c.C3287T', 'p.A1096V', 0.002463, 1218, 'PASS'),
#   ('c.T3139C', 'p.S1047P', 0.0016469999999999998, 1214, 'PASS'),
#   ('c.G3119T', 'p.G1040V', 0.004105, 1218, 'PASS'),
#   ('c.G2972A', 'p.R991H', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.G2960A', 'p.R987Q', 0.002463, 1218, 'PASS'),
#   ('c.A1636G', 'p.I546V', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.G1505A', 'p.R502Q', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.C1504T', 'p.R502W', 0.0016420000000000002, 1218, 'PASS'),
#   ('c.G1453A', 'p.E485K', 0.027915, 1218, 'PASS'),
#   ('c.G1438A', 'p.V480M', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.G1411A', 'p.E471K', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.C1391T', 'p.T464M', 0.025452000000000002, 1218, 'PASS'),
#   ('c.G1376A', 'p.R459H', 0.002463, 1218, 'PASS'),
#   ('c.A1217G', 'p.Q406R', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.C1033T', 'p.P345S', 0.007389, 1218, 'PASS'),
#   ('c.G1001A', 'p.R334Q', 0.0008210000000000001, 1218, 'LowQual'),
#   ('c.G946A', 'p.V316M', 0.004111999999999999, 1216, 'PASS'),
#   ('c.G590A', 'p.R197K', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.T581C', 'p.I194T', 0.002463, 1218, 'PASS'),
#   ('c.G334A', 'p.E112K', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.A85T', 'p.I29F', 0.05665, 1218, 'PASS'),
#   ('c.C17T', 'p.A6V', 0.0008210000000000001, 1218, 'PASS')],
#  'KIAA1161': [],
#  'JAM2': [('c.C21A', 'p.H7Q', 0.021488, 1210, 'PASS'),
#   ('c.C440T', 'p.S147F', 0.004105, 1218, 'PASS'),
#   ('c.C595T', 'p.L199F', 0.0008210000000000001, 1218, 'PASS'),
#   ('c.A748C', 'p.S250R', 0.014778, 1218, 'PASS'),
#   ('c.C878T', 'p.T293M', 0.003817, 524, 'PASS')]}

# %%
slc20a2 = pd.DataFrame(varAnnot['SLC20A2'])

# %%
slc20a2.columns = ['Codon Change', 'Protein Change', 'Frequency', 'Allele Number', 'Filter Pass']

# %%
slc20a2['Gene'] = 'SLC20A2'

# %%
cols = slc20a2.columns.tolist()
cols = cols[-1:] + cols[:-1]
slc20a2 = slc20a2[cols]
slc20a2
# Out:
#       Gene Codon Change Protein Change  Frequency  Allele Number Filter Pass
# 0  SLC20A2  c.G1438A     p.A480T        0.008210   1218           PASS
# 1  SLC20A2  c.C1316T     p.A439V        0.000821   1218           PASS
# 2  SLC20A2  c.C1223T     p.S408L        0.000821   1218           PASS
# 3  SLC20A2  c.G1198A     p.A400T        0.001642   1218           PASS
# 4  SLC20A2  c.G910A      p.G304S        0.050082   1218           PASS
# 5  SLC20A2  c.G761A      p.R254Q        0.000821   1218           PASS
# 6  SLC20A2  c.A533G      p.N178S        0.001642   1218           PASS
# 7  SLC20A2  c.A145G      p.I49V         0.000821   1218           PASS
# 8  SLC20A2  c.T44C       p.I15T         0.000821   1218           PASS

# %%
xpr1 = pd.DataFrame(varAnnot['XPR1'])
xpr1.columns = ['Codon Change', 'Protein Change', 'Frequency', 'Allele Number', 'Filter Pass']
xpr1['Gene'] = 'XPR1'
cols = xpr1.columns.tolist()
cols = cols[-1:] + cols[:-1]
xpr1 = xpr1[cols]

pfbcNSVars = pd.concat([slc20a2, xpr1], join = 'outer')

pdgfb = pd.DataFrame(varAnnot['PDGFB'])
pdgfb.columns = ['Codon Change', 'Protein Change', 'Frequency', 'Allele Number', 'Filter Pass']
pdgfb['Gene'] = 'PDGFB'
cols = pdgfb.columns.tolist()
cols = cols[-1:] + cols[:-1]
pdgfb = pdgfb[cols]

pfbcNSVars = pd.concat([pfbcNSVars, pdgfb], join = 'outer')

pdgfrb = pd.DataFrame(varAnnot['PDGFRB'])
pdgfrb.columns = ['Codon Change', 'Protein Change', 'Frequency', 'Allele Number', 'Filter Pass']
pdgfrb['Gene'] = 'PDGFRB'
cols = pdgfrb.columns.tolist()
cols = cols[-1:] + cols[:-1]
pdgfrb = pdgfrb[cols]

pfbcNSVars = pd.concat([pfbcNSVars, pdgfrb], join = 'outer')

jam2 = pd.DataFrame(varAnnot['JAM2'])
jam2.columns = ['Codon Change', 'Protein Change', 'Frequency', 'Allele Number', 'Filter Pass']
jam2['Gene'] = 'JAM2'
cols = jam2.columns.tolist()
cols = cols[-1:] + cols[:-1]
jam2 = jam2[cols]

pfbcNSVars = pd.concat([pfbcNSVars, jam2], join = 'outer')

# %%
pfbcNSVars
# Out:
#        Gene Codon Change Protein Change  Frequency  Allele Number Filter Pass
# 0   SLC20A2  c.G1438A     p.A480T        0.008210   1218           PASS
# 1   SLC20A2  c.C1316T     p.A439V        0.000821   1218           PASS
# 2   SLC20A2  c.C1223T     p.S408L        0.000821   1218           PASS
# 3   SLC20A2  c.G1198A     p.A400T        0.001642   1218           PASS
# 4   SLC20A2  c.G910A      p.G304S        0.050082   1218           PASS
# 5   SLC20A2  c.G761A      p.R254Q        0.000821   1218           PASS
# 6   SLC20A2  c.A533G      p.N178S        0.001642   1218           PASS
# 7   SLC20A2  c.A145G      p.I49V         0.000821   1218           PASS
# 8   SLC20A2  c.T44C       p.I15T         0.000821   1218           PASS
# 0   XPR1     c.G527T      p.R176L        0.000821   1218           PASS
# 1   XPR1     c.G1310A     p.R437Q        0.000821   1218           LowQual
# 2   XPR1     c.T1811C     p.L604P        0.000821   1218           PASS
# 0   PDGFB    c.C682A      p.H228N        0.000821   1218           PASS
# 1   PDGFB    c.C656T      p.P219L        0.003284   1218           PASS
# 2   PDGFB    c.C635T      p.T212M        0.005747   1218           PASS
# 3   PDGFB    c.A434G      p.Q145R        0.000822   1216           PASS
# 4   PDGFB    c.G35T       p.C12F         0.000821   1218           PASS
# 0   PDGFRB   c.C3287T     p.A1096V       0.002463   1218           PASS
# 1   PDGFRB   c.T3139C     p.S1047P       0.001647   1214           PASS
# 2   PDGFRB   c.G3119T     p.G1040V       0.004105   1218           PASS
# 3   PDGFRB   c.G2972A     p.R991H        0.000821   1218           PASS
# 4   PDGFRB   c.G2960A     p.R987Q        0.002463   1218           PASS
# 5   PDGFRB   c.A1636G     p.I546V        0.000821   1218           PASS
# 6   PDGFRB   c.G1505A     p.R502Q        0.000821   1218           PASS
# 7   PDGFRB   c.C1504T     p.R502W        0.001642   1218           PASS
# 8   PDGFRB   c.G1453A     p.E485K        0.027915   1218           PASS
# 9   PDGFRB   c.G1438A     p.V480M        0.000821   1218           PASS
# 10  PDGFRB   c.G1411A     p.E471K        0.000821   1218           PASS
# 11  PDGFRB   c.C1391T     p.T464M        0.025452   1218           PASS
# 12  PDGFRB   c.G1376A     p.R459H        0.002463   1218           PASS
# 13  PDGFRB   c.A1217G     p.Q406R        0.000821   1218           PASS
# 14  PDGFRB   c.C1033T     p.P345S        0.007389   1218           PASS
# 15  PDGFRB   c.G1001A     p.R334Q        0.000821   1218           LowQual
# 16  PDGFRB   c.G946A      p.V316M        0.004112   1216           PASS
# 17  PDGFRB   c.G590A      p.R197K        0.000821   1218           PASS
# 18  PDGFRB   c.T581C      p.I194T        0.002463   1218           PASS
# 19  PDGFRB   c.G334A      p.E112K        0.000821   1218           PASS
# 20  PDGFRB   c.A85T       p.I29F         0.056650   1218           PASS
# 21  PDGFRB   c.C17T       p.A6V          0.000821   1218           PASS
# 0   JAM2     c.C21A       p.H7Q          0.021488   1210           PASS
# 1   JAM2     c.C440T      p.S147F        0.004105   1218           PASS
# 2   JAM2     c.C595T      p.L199F        0.000821   1218           PASS
# 3   JAM2     c.A748C      p.S250R        0.014778   1218           PASS
# 4   JAM2     c.C878T      p.T293M        0.003817   524            PASS

# %% [markdown]
# Filtrando as variantes de baixa qualidade

# %%
pfbcNSVars = pfbcNSVars[pfbcNSVars['Filter Pass'].str.contains('PASS')]

# %%
pfbcNSVars.drop('Filter Pass', axis=1, inplace = True)

# %%
pfbcNSVars
# Out:
#        Gene Codon Change Protein Change  Frequency  Allele Number
# 0   SLC20A2  c.G1438A     p.A480T        0.008210   1218
# 1   SLC20A2  c.C1316T     p.A439V        0.000821   1218
# 2   SLC20A2  c.C1223T     p.S408L        0.000821   1218
# 3   SLC20A2  c.G1198A     p.A400T        0.001642   1218
# 4   SLC20A2  c.G910A      p.G304S        0.050082   1218
# 5   SLC20A2  c.G761A      p.R254Q        0.000821   1218
# 6   SLC20A2  c.A533G      p.N178S        0.001642   1218
# 7   SLC20A2  c.A145G      p.I49V         0.000821   1218
# 8   SLC20A2  c.T44C       p.I15T         0.000821   1218
# 0   XPR1     c.G527T      p.R176L        0.000821   1218
# 2   XPR1     c.T1811C     p.L604P        0.000821   1218
# 0   PDGFB    c.C682A      p.H228N        0.000821   1218
# 1   PDGFB    c.C656T      p.P219L        0.003284   1218
# 2   PDGFB    c.C635T      p.T212M        0.005747   1218
# 3   PDGFB    c.A434G      p.Q145R        0.000822   1216
# 4   PDGFB    c.G35T       p.C12F         0.000821   1218
# 0   PDGFRB   c.C3287T     p.A1096V       0.002463   1218
# 1   PDGFRB   c.T3139C     p.S1047P       0.001647   1214
# 2   PDGFRB   c.G3119T     p.G1040V       0.004105   1218
# 3   PDGFRB   c.G2972A     p.R991H        0.000821   1218
# 4   PDGFRB   c.G2960A     p.R987Q        0.002463   1218
# 5   PDGFRB   c.A1636G     p.I546V        0.000821   1218
# 6   PDGFRB   c.G1505A     p.R502Q        0.000821   1218
# 7   PDGFRB   c.C1504T     p.R502W        0.001642   1218
# 8   PDGFRB   c.G1453A     p.E485K        0.027915   1218
# 9   PDGFRB   c.G1438A     p.V480M        0.000821   1218
# 10  PDGFRB   c.G1411A     p.E471K        0.000821   1218
# 11  PDGFRB   c.C1391T     p.T464M        0.025452   1218
# 12  PDGFRB   c.G1376A     p.R459H        0.002463   1218
# 13  PDGFRB   c.A1217G     p.Q406R        0.000821   1218
# 14  PDGFRB   c.C1033T     p.P345S        0.007389   1218
# 16  PDGFRB   c.G946A      p.V316M        0.004112   1216
# 17  PDGFRB   c.G590A      p.R197K        0.000821   1218
# 18  PDGFRB   c.T581C      p.I194T        0.002463   1218
# 19  PDGFRB   c.G334A      p.E112K        0.000821   1218
# 20  PDGFRB   c.A85T       p.I29F         0.056650   1218
# 21  PDGFRB   c.C17T       p.A6V          0.000821   1218
# 0   JAM2     c.C21A       p.H7Q          0.021488   1210
# 1   JAM2     c.C440T      p.S147F        0.004105   1218
# 2   JAM2     c.C595T      p.L199F        0.000821   1218
# 3   JAM2     c.A748C      p.S250R        0.014778   1218
# 4   JAM2     c.C878T      p.T293M        0.003817   524

# %% [markdown]
# O MYORG (KIAA1161) não está bem anotado no banco de dados ABraOM. Vamos precisar extrair suas informaçẽos a partir da posição cromossômica das variantes.

# %%
pfbcAbraom['KIAA1161']
# Out:
#         Chr     Start    Ref Alt PredictedFunc.refGene Gene.refGene          PredConsequence.refGene     avsnp147                         FILTER CEGH Filter  HomozygousALT count  Hemizygous count  Allele number  Allele ALT count  Frequencies   Cohort
# 1081663  9   34368674  A      G   UTR3                  KIAA1161     NM_020702:c.*2123T>C             rs7861760    PASS                           FDP         10                   0                 108            22                0.203704     SABE609
# 1081664  9   34368984  G      T   UTR3                  KIAA1161     NM_020702:c.*1813C>A             rs3892388    PASS                           FDP         32                   0                 464            72                0.155172     SABE609
# 1081665  9   34369027  C      T   UTR3                  KIAA1161     NM_020702:c.*1770G>A             NaN          LowQual                        FDP         1                    0                 582            2                 0.003436     SABE609
# 1081666  9   34369062  C      G   UTR3                  KIAA1161     NM_020702:c.*1735G>C             rs1134455    PASS                           FDP         46                   0                 528            105               0.198864     SABE609
# 1081667  9   34369374  G      T   UTR3                  KIAA1161     NM_020702:c.*1423C>A             NaN          PASS                           FDP         1                    0                 426            2                 0.004695     SABE609
# 1081668  9   34369683  TGAGA  -   UTR3                  KIAA1161     NM_020702:c.*1114_*1110delTCTCA  rs374451075  PASS                           FDP         38                   0                 496            84                0.169355     SABE609
# 1081669  9   34369718  A      T   UTR3                  KIAA1161     NM_020702:c.*1079T>A             NaN          LowQual                        FDP         1                    0                 456            2                 0.004386     SABE609
# 1081670  9   34370002  TC     -   UTR3                  KIAA1161     NM_020702:c.*795_*794delGA       rs149223881  PASS                           FDP         22                   0                 432            62                0.143519     SABE609
# 1081671  9   34370020  T      A   UTR3                  KIAA1161     NM_020702:c.*777A>T              rs10758255   PASS                           FDP         120                  0                 422            252               0.597156     SABE609
# 1081672  9   34370266  G      T   UTR3                  KIAA1161     NM_020702:c.*531C>A              NaN          LowQual                        FDP         0                    0                 448            1                 0.002232     SABE609
# 1081673  9   34370438  G      A   UTR3                  KIAA1161     NM_020702:c.*359C>T              NaN          LowQual                        FDP         1                    0                 672            2                 0.002976     SABE609
# 1081674  9   34370476  C      T   UTR3                  KIAA1161     NM_020702:c.*321G>A              NaN          LowQual                        FDP         0                    0                 816            1                 0.001225     SABE609
# 1081675  9   34370542  G      A   UTR3                  KIAA1161     NM_020702:c.*255C>T              rs558324774  LowQual                        FDP         0                    0                 1098           1                 0.000911     SABE609
# 1081676  9   34370701  T      -   UTR3                  KIAA1161     NM_020702:c.*96delA              rs528652691  VQSRTrancheINDEL99.00to99.90   SR          318                  0                 1218           809               0.664204     SABE609
# 1081677  9   34370702  G      -   UTR3                  KIAA1161     NM_020702:c.*95delC              rs398096380  PASS                           vSR         337                  0                 1218           900               0.738916     SABE609
# 1081678  9   34370705  A      -   UTR3                  KIAA1161     NM_020702:c.*92delT              rs200098063  VQSRTrancheINDEL99.90to100.00  WK-LowCall  97                   0                 1218           468               0.384236     SABE609
# 1081679  9   34370782  G      A   UTR3                  KIAA1161     NM_020702:c.*15C>T               rs755830209  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081680  9   34370905  G      A   unknown               KIAA1161     UNKNOWN                          rs775768418  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081681  9   34370965  C      G   unknown               KIAA1161     UNKNOWN                          rs199990841  PASS                           vSR         0                    0                 1218           2                 0.001642     SABE609
# 1081682  9   34370975  A      G   unknown               KIAA1161     UNKNOWN                          rs370944350  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081683  9   34371164  G      A   unknown               KIAA1161     UNKNOWN                          NaN          PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081684  9   34371171  T      C   unknown               KIAA1161     UNKNOWN                          rs115786753  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081685  9   34371282  C      T   unknown               KIAA1161     UNKNOWN                          rs749897076  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081686  9   34371358  G      A   unknown               KIAA1161     UNKNOWN                          NaN          PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081687  9   34371424  G      A   unknown               KIAA1161     UNKNOWN                          rs369042834  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081688  9   34371454  G      C   unknown               KIAA1161     UNKNOWN                          rs41311426   PASS                           vSR         0                    0                 1218           14                0.011494     SABE609
# 1081689  9   34371529  C      A   unknown               KIAA1161     UNKNOWN                          rs767224436  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081690  9   34371673  C      A   unknown               KIAA1161     UNKNOWN                          rs764057941  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081691  9   34371699  G      A   unknown               KIAA1161     UNKNOWN                          NaN          PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081692  9   34371740  C      G   unknown               KIAA1161     UNKNOWN                          NaN          PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081693  9   34371788  A      T   unknown               KIAA1161     UNKNOWN                          rs7852399    PASS                           vSR         23                   0                 1218           252               0.206897     SABE609
# 1081694  9   34371832  G      A   unknown               KIAA1161     UNKNOWN                          rs766107041  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081695  9   34371878  A      C   unknown               KIAA1161     UNKNOWN                          rs115412086  PASS                           vSR         0                    0                 1218           3                 0.002463     SABE609
# 1081696  9   34371999  C      T   unknown               KIAA1161     UNKNOWN                          rs41312814   PASS                           vSR         0                    0                 1218           3                 0.002463     SABE609
# 1081697  9   34372014  G      A   unknown               KIAA1161     UNKNOWN                          rs202003652  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081698  9   34372252  T      C   unknown               KIAA1161     UNKNOWN                          rs202011793  PASS                           vSR         0                    0                 1218           4                 0.003284     SABE609
# 1081699  9   34372347  G      T   unknown               KIAA1161     UNKNOWN                          rs12377      PASS                           SR          0                    0                 1218           24                0.019704     SABE609
# 1081700  9   34372382  C      G   unknown               KIAA1161     UNKNOWN                          rs780531156  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081701  9   34372452  C      T   unknown               KIAA1161     UNKNOWN                          rs541063329  PASS                           FDP         0                    0                 1218           1                 0.000821     SABE609
# 1081702  9   34372579  G      A   unknown               KIAA1161     UNKNOWN                          rs74600562   PASS                           vSR         0                    0                 1218           7                 0.005747     SABE609
# 1081703  9   34372769  A      G   unknown               KIAA1161     UNKNOWN                          NaN          PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081704  9   34372783  G      C   unknown               KIAA1161     UNKNOWN                          rs4879781    PASS                           vSR         549                  0                 1218           1153              0.946634     SABE609
# 1081705  9   34372873  C      G   unknown               KIAA1161     UNKNOWN                          rs4879782    PASS                           vSR         343                  0                 1218           907               0.744663     SABE609
# 1081706  9   34372931  T      A   unknown               KIAA1161     UNKNOWN                          rs2297776    PASS                           vSR         14                   0                 1218           204               0.167488     SABE609
# 1081707  9   34372937  A      G   unknown               KIAA1161     UNKNOWN                          rs202207332  PASS                           vSR         0                    0                 1218           1                 0.000821     SABE609
# 1081708  9   34373041  C      T   intronic              KIAA1161     NaN                              rs10972084   PASS                           vSR         14                   0                 1218           144               0.118227     SABE609
# 1081709  9   34373236  G      T   intronic              KIAA1161     NaN                              NaN          LowQual                        FDP         0                    0                 606            1                 0.001650     SABE609
# 1081710  9   34376525  G      T   intronic              KIAA1161     NaN                              NaN          LowQual                        FDP         0                    0                 534            1                 0.001873     SABE609
# 1081711  9   34376670  G      T   intronic              KIAA1161     NaN                              NaN          LowQual                        FDP         0                    0                 732            1                 0.001366     SABE609
# 1081712  9   34376872  C      T   UTR5                  KIAA1161     NM_020702:c.-3931G>A             NaN          LowQual                        FDP         1                    0                 846            2                 0.002364     SABE609
# 1081713  9   34376877  C      T   UTR5                  KIAA1161     NM_020702:c.-3936G>A             NaN          LowQual                        FDP         0                    0                 820            1                 0.001220     SABE609
# 1081714  9   34376998  C      T   upstream              KIAA1161     NaN                              rs191077117  PASS                           FDP         1                    0                 890            4                 0.004494     SABE609

# %% [markdown]
# Extraídas as variantes, vamos comparar agora com as variantes encontradas em pacientes com CCFP.<br>
# Para isso usaremos quatro bancos de dados de anotações de variantes clínicas:<br>
# * O Human Gene Mutation Database (HGMD) - http://www.hgmd.cf.ac.uk/ac/index.php <br>
# * O ClinVar (NCBI) - https://www.ncbi.nlm.nih.gov/clinvar/ <br>
# * E o Leiden Open Variation Database (Coppola Lab) - https://coppolalab.ucla.edu/lovd_pfbc/genes <br>

# %% [markdown]
# # Carregando o banco de dados do ClinVar
#
# A análise do banco do ClinVar incluiu a pesquisa pela palavra-chave 'Primary Familial Brain Calcification'. <br>
# A tabela com todas as variantes foi baixada como arquivo de texto tabular.<br>

# %%
clinVar = pd.read_csv('clinvarPfbc.txt', sep = '\t')

# %%
clinVar.head()
# Out:
#                                                  Name                                               Gene(s)                                                                                                                                                                Condition(s)                                      Clinical significance (Last reviewed)                                   Review status  GRCh37Chromosome       GRCh37Location  GRCh38Chromosome       GRCh38Location  VariationID  AlleleID(s)  Unnamed: 11
# 0  NC_000008.10:g.42338721_42916885del578165           CHRNB3|FNTA|SLC20A2|CHRNA6|THAP1|RNF170|HOOK3|SMIM19  Idiopathic basal ganglia calcification 1                                                                                                                                    Likely pathogenic                                                          no assertion criteria provided                  8.0               42338721 - 42916885 NaN                NaN                  236030       237596      NaN
# 1  NM_001278074.1(COL5A1):c.514G>T (p.Val172Phe)       COL5A1                                                Connective tissue disorder|Cardiovascular phenotype|Aortic valve disorder|Thoracic aortic aneurysm and aortic dissection|Ehlers-Danlos syndrome, classic type|not provided  Conflicting interpretations of pathogenicity(Last reviewed: Dec 18, 2018)  criteria provided, conflicting interpretations  9.0               137593039            9.0               134701193            180298       178594      NaN
# 2  MYORG, ILE655THR                                    MYORG                                                 BASAL GANGLIA CALCIFICATION, IDIOPATHIC, 7, AUTOSOMAL RECESSIVE                                                                                                             Pathogenic(Last reviewed: Feb 8, 2019)                                     no assertion criteria provided                 NaN                NaN                 NaN                NaN                  617697       609100      NaN
# 3  NM_020702.5(MYORG):c.1057_1059GAC[1] (p.Asp354del)  MYORG                                                 BASAL GANGLIA CALCIFICATION, IDIOPATHIC, 7, AUTOSOMAL RECESSIVE                                                                                                             Pathogenic(Last reviewed: Feb 8, 2019)                                     no assertion criteria provided                  9.0               34371880 - 34371882  9.0               34371882 - 34371884  617696       609099      NaN
# 4  NM_020702.5(MYORG):c.1233del (p.Phe411fs)           MYORG                                                 BASAL GANGLIA CALCIFICATION, IDIOPATHIC, 7, AUTOSOMAL RECESSIVE                                                                                                             Pathogenic(Last reviewed: Feb 8, 2019)                                     no assertion criteria provided                  9.0               34371709             9.0               34371711             617695       609098      NaN

# %%
clinVar['Gene(s)'].unique()
# Out:
# array(['CHRNB3|FNTA|SLC20A2|CHRNA6|THAP1|RNF170|HOOK3|SMIM19', 'COL5A1',
#        'MYORG', 'PDGFB', 'PDGFRB', 'SLC20A2', 'SLC20A2|SMIM19', 'SUFU',
#        'XPR1'], dtype=object)

# %%
clinVars = dict('SLC20A2': clinVar[clinVar['Gene(s)'].str.contains('SLC20A2')])
clinSLC20A2 = clinVar[clinVar['Gene(s)'].str.contains('SLC20A2')]
clinXPR1 = clinVar[clinVar['Gene(s)'].str.contains('XPR1')]
clinPDGFB = clinVar[clinVar['Gene(s)'].str.contains('PDGFB')]
clinPDGFRB = clinVar[clinVar['Gene(s)'].str.contains('PDGFRB')]
clinMYORG = clinVar[clinVar['Gene(s)'].str.contains('MYORG')]

# %%
clinSLC20A2
# Out:
#                                                 Name                                               Gene(s)                              Condition(s)           Clinical significance (Last reviewed)                        Review status  GRCh37Chromosome       GRCh37Location  GRCh38Chromosome GRCh38Location  VariationID  AlleleID(s)  Unnamed: 11
# 0    NC_000008.10:g.42338721_42916885del578165        CHRNB3|FNTA|SLC20A2|CHRNA6|THAP1|RNF170|HOOK3|SMIM19  Idiopathic basal ganglia calcification 1  Likely pathogenic                               no assertion criteria provided       8.0               42338721 - 42916885 NaN                NaN            236030       237596      NaN
# 44   NM_006749.5(SLC20A2):c.935-2A>G                  SLC20A2                                               Idiopathic basal ganglia calcification 1  Pathogenic(Last reviewed: Dec 17, 2018)         criteria provided, single submitter  8.0               42295097             8.0               42437579       636249       624067      NaN
# 45   NM_001257180.2(SLC20A2):c.21del (p.Leu7fs)       SLC20A2                                               Idiopathic basal ganglia calcification 1  Likely pathogenic(Last reviewed: Nov 30, 2018)  no assertion criteria provided       8.0               42329888             8.0               42472370       634898       622734      NaN
# 46   NM_001257180.2(SLC20A2):c.1795-1G>A              SLC20A2                                               Idiopathic basal ganglia calcification 1  Likely pathogenic(Last reviewed: Nov 30, 2018)  no assertion criteria provided       8.0               42275486             8.0               42417968       634897       622737      NaN
# 47   NM_001257180.2(SLC20A2):c.303del (p.Trp101fs)    SLC20A2                                               Idiopathic basal ganglia calcification 1  Likely pathogenic(Last reviewed: Nov 30, 2018)  no assertion criteria provided       8.0               42323422             8.0               42465905       634896       622731      NaN
# ..                                             ...        ...                                                                                    ...                                             ...                             ...       ...                    ...             ...                    ...          ...          ...       ..
# 116  NM_006749.5(SLC20A2):c.1784C>T (p.Thr595Met)     SLC20A2                                               Idiopathic basal ganglia calcification 1  Pathogenic(Last reviewed: Feb 12, 2012)         no assertion criteria provided       8.0               42286286             8.0               42428768       29797        38752       NaN
# 117  NM_001257180.2(SLC20A2):c.1723G>A (p.Glu575Lys)  SLC20A2                                               Idiopathic basal ganglia calcification 1  Likely pathogenic(Last reviewed: Nov 21, 2017)  criteria provided, single submitter  8.0               42286347             8.0               42428829       29796        38751       NaN
# 118  NM_001257180.2(SLC20A2):c.1802C>T (p.Ser601Leu)  SLC20A2                                               Idiopathic basal ganglia calcification 1  Pathogenic(Last reviewed: Jun 27, 2013)         no assertion criteria provided       8.0               42275478             8.0               42417960       29795        38750       NaN
# 119  NM_001257180.2(SLC20A2):c.1802C>G (p.Ser601Trp)  SLC20A2                                               Idiopathic basal ganglia calcification 1  Pathogenic(Last reviewed: Jun 27, 2013)         no assertion criteria provided       8.0               42275478             8.0               42417960       29794        38749       NaN
# 120  NM_001257180.2(SLC20A2):c.1492G>A (p.Gly498Arg)  SLC20A2                                               Idiopathic basal ganglia calcification 1  Pathogenic(Last reviewed: Feb 12, 2012)         no assertion criteria provided       8.0               42294538             8.0               42437020       29793        38748       NaN
#
# [78 rows x 12 columns]

# %%
clinVariants = dict()
proteinChange = []
codonChange = []
clinicalSig = []

def extractClinVar(df):
    for idx in enumerate(df['Name']):
        for s in df['Name']:
            if 'NM' in s:
                if '(' in s[s.find('c.'):]:
                    #print(s[s.find('c.'):s.find(' ')])
                    codon = s[s.find('c.'):s.find(' ')]
                    aminoacid = s[s.find('p.'):-1]
                    if idx[1] in s:
                        patho = df.iloc[idx[0]]['Clinical significance (Last reviewed)']
                        clinVariants[codon] = (codon, aminoacid, patho)

                        codonChange.append(s[s.find('c.'):s.find(' ')])
                        proteinChange.append(s[s.find('p.'):-1])
                else:
                    codonChange.append(s[s.find('c.'):])
                    codon = s[s.find('c.'):]
                    if idx[1] in s:
                        patho = df.iloc[idx[0]]['Clinical significance (Last reviewed)']
                        clinVariants[codon] = (codon, patho)
                    
                
    return codonChange, proteinChange, clinVariants

# %%
extractClinVar(clinSLC20A2)
# Out:
# (['c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.21del',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.303del',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.1196A>C',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.187G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.188G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.1520_1521del',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.1375G>T',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.1723G>T',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.136C>T',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.138G>A',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.186A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.345G>A',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.553G>C',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   'c.*538C>T',
#   'c.*570G>T',
#   'c.*660T>C',
#   'c.*926C>T',
#   'c.*1057C>G',
#   'c.*1069G>C',
#   'c.935-2A>G',
#   'c.1795-1G>A',
#   'c.-5+443G>A',
#   'c.-5+419G>T',
#   'c.-5+385T>A',
#   'c.-5+308C>A',
#   'c.-5+287G>A',
#   'c.-389G>A',
#   'c.-305G>A',
#   'c.-288G>C',
#   'c.-265+3dup',
#   'c.-265+7dup',
#   'c.-89A>G',
#   'c.290-13C>A',
#   'c.290-5T>C',
#   'c.678C>T',
#   'c.*70C>T',
#   'c.*112G>T',
#   'c.*113A>T',
#   'c.*124G>T',
#   'c.*171G>A',
#   'c.*263A>C',
#   'c.*289A>C',
#   'c.*361A>G',
#   'c.*380C>T',
#   'c.*409A>G',
#   ...],
#  ['p.Leu7fs',
#   'p.Trp101fs',
#   'p.His399Pro',
#   'p.Gly63Ser',
#   'p.Gly63Asp',
#   'p.Val507fs',
#   'p.Glu459Ter',
#   'p.Glu575Ter',
#   'p.Gln46Ter',
#   'p.Gln46=',
#   'p.Leu62=',
#   'p.Thr115=',
#   'p.Val185Leu',
#   'p.Phe226=',
#   'p.Arg254Gln',
#   'p.Val263Ile',
#   'p.Lys278=',
#   'p.Asp282=',
#   'p.Ser283=',
#   'p.Leu295=',
#   'p.Ala303=',
#   'p.Gly304Ser',
#   'p.Tyr311=',
#   'p.His336=',
#   'p.Thr337=',
#   'p.Asp364Asn',
#   'p.Arg378=',
#   'p.Gly418=',
#   'p.Glu459Asp',
#   'p.Ala480Thr',
#   'p.Gly524=',
#   'p.Val526Leu',
#   'p.Ser601=',
#   'p.Ser637=',
#   'p.Leu20=',
#   'p.Ala604=',
#   'p.Ile169_Leu170insTer',
#   'p.Val195fs',
#   'p.Ser610fs',
#   'p.Thr595Met',
#   'p.Glu575Lys',
#   'p.Ser601Leu',
#   'p.Ser601Trp',
#   'p.Gly498Arg'],
#  {'c.935-2A>G': ('c.935-2A>G', 'Pathogenic(Last reviewed: Dec 17, 2018)'),
#   'c.21del': ('c.21del',
#    'p.Leu7fs',
#    'Likely pathogenic(Last reviewed: Nov 30, 2018)'),
#   'c.1795-1G>A': ('c.1795-1G>A',
#    'Likely pathogenic(Last reviewed: Nov 30, 2018)'),
#   'c.303del': ('c.303del',
#    'p.Trp101fs',
#    'Likely pathogenic(Last reviewed: Nov 30, 2018)'),
#   'c.1196A>C': ('c.1196A>C',
#    'p.His399Pro',
#    'Likely pathogenic(Last reviewed: Nov 30, 2018)'),
#   'c.187G>A': ('c.187G>A',
#    'p.Gly63Ser',
#    'Likely pathogenic(Last reviewed: Nov 30, 2018)'),
#   'c.188G>A': ('c.188G>A',
#    'p.Gly63Asp',
#    'Likely pathogenic(Last reviewed: Nov 30, 2018)'),
#   'c.1520_1521del': ('c.1520_1521del',
#    'p.Val507fs',
#    'Likely pathogenic(Last reviewed: Nov 30, 2018)'),
#   'c.1375G>T': ('c.1375G>T',
#    'p.Glu459Ter',
#    'Pathogenic(Last reviewed: May 18, 2018)'),
#   'c.1723G>T': ('c.1723G>T',
#    'p.Glu575Ter',
#    'Pathogenic(Last reviewed: Oct 25, 2016)'),
#   'c.136C>T': ('c.136C>T',
#    'p.Gln46Ter',
#    'Pathogenic(Last reviewed: Jul 15, 2016)'),
#   'c.-5+443G>A': ('c.-5+443G>A', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.-5+419G>T': ('c.-5+419G>T',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.-5+385T>A': ('c.-5+385T>A', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.-5+308C>A': ('c.-5+308C>A',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.-5+287G>A': ('c.-5+287G>A',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.-389G>A': ('c.-389G>A',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.-305G>A': ('c.-305G>A', 'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.-288G>C': ('c.-288G>C',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.-265+3dup': ('c.-265+3dup',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.-265+7dup': ('c.-265+7dup',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.-89A>G': ('c.-89A>G', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.138G>A': ('c.138G>A',
#    'p.Gln46=',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.186A>G': ('c.186A>G',
#    'p.Leu62=',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.290-13C>A': ('c.290-13C>A', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.290-5T>C': ('c.290-5T>C', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.345G>A': ('c.345G>A',
#    'p.Thr115=',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.553G>C': ('c.553G>C',
#    'p.Val185Leu',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.678C>T': ('c.678C>T',
#    'p.Phe226=',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.761G>A': ('c.761G>A',
#    'p.Arg254Gln',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.787G>A': ('c.787G>A',
#    'p.Val263Ile',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.834G>A': ('c.834G>A',
#    'p.Lys278=',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.846C>T': ('c.846C>T',
#    'p.Asp282=',
#    'Conflicting interpretations of pathogenicity(Last reviewed: Apr 18, 2017)'),
#   'c.849C>T': ('c.849C>T',
#    'p.Ser283=',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.883C>T': ('c.883C>T',
#    'p.Leu295=',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.909G>A': ('c.909G>A',
#    'p.Ala303=',
#    'Benign/Likely benign(Last reviewed: Jun 28, 2017)'),
#   'c.910G>A': ('c.910G>A',
#    'p.Gly304Ser',
#    'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.933C>T': ('c.933C>T',
#    'p.Tyr311=',
#    'Likely benign(Last reviewed: Jun 28, 2017)'),
#   'c.1008C>T': ('c.1008C>T',
#    'p.His336=',
#    'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.1011C>A': ('c.1011C>A',
#    'p.Thr337=',
#    'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.1090G>A': ('c.1090G>A',
#    'p.Asp364Asn',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.1134G>T': ('c.1134G>T',
#    'p.Arg378=',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.1254C>T': ('c.1254C>T',
#    'p.Gly418=',
#    'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.1377G>T': ('c.1377G>T',
#    'p.Glu459Asp',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.1438G>A': ('c.1438G>A',
#    'p.Ala480Thr',
#    'Benign/Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.1572C>T': ('c.1572C>T',
#    'p.Gly524=',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.1576G>T': ('c.1576G>T',
#    'p.Val526Leu',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.1803G>A': ('c.1803G>A',
#    'p.Ser601=',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.1911C>T': ('c.1911C>T',
#    'p.Ser637=',
#    'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*70C>T': ('c.*70C>T', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*112G>T': ('c.*112G>T', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*113A>T': ('c.*113A>T', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*124G>T': ('c.*124G>T',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.*171G>A': ('c.*171G>A',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.*263A>C': ('c.*263A>C', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*289A>C': ('c.*289A>C',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.*361A>G': ('c.*361A>G', 'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.*380C>T': ('c.*380C>T', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*409A>G': ('c.*409A>G', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*538C>T': ('c.*538C>T',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.*570G>T': ('c.*570G>T', 'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.*660T>C': ('c.*660T>C',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.*926C>T': ('c.*926C>T', 'Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.*1057C>G': ('c.*1057C>G', 'Benign(Last reviewed: Jun 14, 2016)'),
#   'c.*1069G>C': ('c.*1069G>C',
#    'Uncertain significance(Last reviewed: Jun 14, 2016)'),
#   'c.58T>C': ('c.58T>C',
#    'p.Leu20=',
#    'Benign/Likely benign(Last reviewed: Jun 14, 2016)'),
#   'c.1812C>T': ('c.1812C>T',
#    'p.Ala604=',
#    'Benign/Likely benign(Last reviewed: Jun 28, 2017)'),
#   'c.509del': ('c.509del',
#    'p.Ile169_Leu170insTer',
#    'Pathogenic(Last reviewed: Dec 23, 2015)'),
#   'c.583_584del': ('c.583_584del',
#    'p.Val195fs',
#    'Pathogenic(Last reviewed: Aug 10, 2018)'),
#   'c.1828_1831del': ('c.1828_1831del',
#    'p.Ser610fs',
#    'Pathogenic(Last reviewed: Feb 1, 2013)'),
#   'c.1784C>T': ('c.1784C>T',
#    'p.Thr595Met',
#    'Pathogenic(Last reviewed: Feb 12, 2012)'),
#   'c.1723G>A': ('c.1723G>A',
#    'p.Glu575Lys',
#    'Likely pathogenic(Last reviewed: Nov 21, 2017)'),
#   'c.1802C>T': ('c.1802C>T',
#    'p.Ser601Leu',
#    'Pathogenic(Last reviewed: Jun 27, 2013)'),
#   'c.1802C>G': ('c.1802C>G',
#    'p.Ser601Trp',
#    'Pathogenic(Last reviewed: Jun 27, 2013)'),
#   'c.1492G>A': ('c.1492G>A',
#    'p.Gly498Arg',
#    'Pathogenic(Last reviewed: Feb 12, 2012)')})

# %%
clinVariants.keys()
# Out:
# dict_keys(['c.935-2A>G', 'c.21del', 'c.1795-1G>A', 'c.303del', 'c.1196A>C', 'c.187G>A', 'c.188G>A', 'c.1520_1521del', 'c.1375G>T', 'c.1723G>T', 'c.136C>T', 'c.-5+443G>A', 'c.-5+419G>T', 'c.-5+385T>A', 'c.-5+308C>A', 'c.-5+287G>A', 'c.-389G>A', 'c.-305G>A', 'c.-288G>C', 'c.-265+3dup', 'c.-265+7dup', 'c.-89A>G', 'c.138G>A', 'c.186A>G', 'c.290-13C>A', 'c.290-5T>C', 'c.345G>A', 'c.553G>C', 'c.678C>T', 'c.761G>A', 'c.787G>A', 'c.834G>A', 'c.846C>T', 'c.849C>T', 'c.883C>T', 'c.909G>A', 'c.910G>A', 'c.933C>T', 'c.1008C>T', 'c.1011C>A', 'c.1090G>A', 'c.1134G>T', 'c.1254C>T', 'c.1377G>T', 'c.1438G>A', 'c.1572C>T', 'c.1576G>T', 'c.1803G>A', 'c.1911C>T', 'c.*70C>T', 'c.*112G>T', 'c.*113A>T', 'c.*124G>T', 'c.*171G>A', 'c.*263A>C', 'c.*289A>C', 'c.*361A>G', 'c.*380C>T', 'c.*409A>G', 'c.*538C>T', 'c.*570G>T', 'c.*660T>C', 'c.*926C>T', 'c.*1057C>G', 'c.*1069G>C', 'c.58T>C', 'c.1812C>T', 'c.509del', 'c.583_584del', 'c.1828_1831del', 'c.1784C>T', 'c.1723G>A', 'c.1802C>T', 'c.1802C>G', 'c.1492G>A'])

# %%
aminoacids = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
     'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N', 
     'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W', 
     'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M'}

# %%
def reduceVar(proteinChange):
    for i in enumerate(proteinChange):
        var = str(i[1]).upper()
        for a in aminoacids.keys():
            if a in var:
                proteinChange[i[0]] = var[0:var.find(a)] + aminoacids[a] + var[var.find(a)+3:]
    for i in enumerate(proteinChange):
        var = str(i[1]).upper()
        for a in aminoacids.keys():
            if a in var:
                proteinChange[i[0]] = var[0:var.find(a)] + aminoacids[a] + var[var.find(a)+3:]

# %%
reduceVar(proteinChange)
proteinChange
# Out:
# ['P.L7FS',
#  'P.W101FS',
#  'P.H399P',
#  'P.G63S',
#  'P.G63D',
#  'P.V507FS',
#  'P.E459TER',
#  'P.E575TER',
#  'P.Q46TER',
#  'P.Q46=',
#  'P.L62=',
#  'P.T115=',
#  'P.V185L',
#  'P.F226=',
#  'P.R254Q',
#  'P.V263I',
#  'P.K278=',
#  'P.D282=',
#  'P.S283=',
#  'P.L295=',
#  'P.A303=',
#  'P.G304S',
#  'P.Y311=',
#  'P.H336=',
#  'P.T337=',
#  'P.D364N',
#  'P.R378=',
#  'P.G418=',
#  'P.E459D',
#  'P.A480T',
#  'P.G524=',
#  'P.V526L',
#  'P.S601=',
#  'P.S637=',
#  'P.L20=',
#  'P.A604=',
#  'P.I169_L170INSTER',
#  'P.V195FS',
#  'P.S610FS',
#  'P.T595M',
#  'P.E575K',
#  'P.S601L',
#  'P.S601W',
#  'P.G498R']

# %%
abraomPFBC = dict()
variantlist = []
def vartodict(gene, variantlist):
    for var in pfbcNSVars[pfbcNSVars['Gene'].str.contains(gene)]['Protein Change']:
        variant = var.upper()
        if variant in variantlist:
            abraomPFBC[var] = pfbcNSVars[pfbcNSVars['Protein Change'].str.contains(var)]

# %%
vartodict('SLC20A2', proteinChange)

# %%
abraomPFBC
# Out:
# {'p.A480T':       Gene Codon Change Protein Change  Frequency  Allele Number
#  0  SLC20A2  c.G1438A     p.A480T        0.00821    1218         ,
#  'p.G304S':       Gene Codon Change Protein Change  Frequency  Allele Number
#  4  SLC20A2  c.G910A      p.G304S        0.050082   1218         ,
#  'p.R254Q':       Gene Codon Change Protein Change  Frequency  Allele Number
#  5  SLC20A2  c.G761A      p.R254Q        0.000821   1218         }
